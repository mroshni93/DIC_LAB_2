# %%
#Kshitij Goel
#Roshni Murali

from nytimesarticle import articleAPI
#'8b18491cab36479486581b2c19309a5e'
#56e3a6914e34457d9e1ea6c6d2c588b1
api = articleAPI('56e3a6914e34457d9e1ea6c6d2c588b1')
articles = api.search( q = "homework", begin_date = 20180303)
print(articles)
# Out:
# {'status': 'OK', 'copyright': 'Copyright (c) 2018 The New York Times Company. All Rights Reserved.', 'response': {'docs': [{'web_url': 'https://www.nytimes.com/2018/04/04/nyregion/homework-therapists-tutoring-counseling-new-york.html', 'snippet': 'The tutors deal not in plain-old schoolwork or straight-up counseling, but in a blend of the two, offering academic and psychological support, at a price.', 'print_page': '22', 'blog': {}, 'source': 'The New York Times', 'multimedia': [{'rank': 0, 'subtype': 'xlarge', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2018/04/05/nyregion/05HOMEWORK1/05HOMEWORK-alpha-articleLarge.jpg', 'height': 400, 'width': 600, 'legacy': {'xlarge': 'images/2018/04/05/nyregion/05HOMEWORK1/05HOMEWORK-alpha-articleLarge.jpg', 'xlargewidth': 600, 'xlargeheight': 400}, 'subType': 'xlarge', 'crop_name': 'articleLarge'}, {'rank': 0, 'subtype': 'wide', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2018/04/05/nyregion/05HOMEWORK1/0
# ...

# %%
import unicodedata

ls = []
for article in articles['response']['docs']:
    ls.append(article['web_url'].encode('utf-8'))
   
print(ls)
# Out:
# [b'https://www.nytimes.com/2018/04/04/nyregion/homework-therapists-tutoring-counseling-new-york.html', b'https://www.nytimes.com/aponline/2018/05/02/world/africa/ap-un-united-nations-south-sudan.html', b'https://www.nytimes.com/2018/03/24/opinion/trade-and-the-cities-wonkish.html', b'https://www.nytimes.com/2018/03/28/learning/lesson-plans/reader-idea-rhythm-rhyme-and-haggis-celebrating-the-poetry-of-robert-burns.html', b'https://www.nytimes.com/2018/03/23/style/watches-collecting.html', b'https://www.nytimes.com/2018/05/10/learning/fortnite-freedom-of-the-press-cyberbullying-and-celebrity-opinions-our-favorite-student-comments-of-the-week.html', b'https://www.nytimes.com/2018/03/15/opinion/paul-krugman-aluminum-steel-trade-tariffs.html', b'https://www.nytimes.com/2018/05/03/learning/self-expression-procrastination-breakdancing-and-childhood-bedrooms-our-favorite-student-comments-of-the-week.html']

# %%
from bs4 import BeautifulSoup
import requests
import unicodedata
import string
import io
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

def clean(s):
    return ''.join(c for c in s if not c in string.punctuation)

def replace(soup):
    for child in soup.children:
        if child.string:
            child.string = ''.join([ch for ch in child.string if ch in alphabet])
        else:
            replace(child)
            

for x in ls[:]:
    page = requests.get(x)
    soup = BeautifulSoup(page.content, 'html.parser')
    soup = soup.find('article')
    alphabet = 'abcdefghijklmnopqrtsuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ '
    replace(soup)
            
    for script in soup(["script", "style"]):
        script.extract() 
    text = soup.text.strip()
    lines = (line.strip() for line in text.splitlines())
    chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
    text = ' '.join(chunk for chunk in chunks if chunk)
    text.encode('utf-8')
    formatted=unicodedata.normalize('NFKD', text).encode('ascii','ignore')
  #  f = open( 'annexure.txt', 'a' )
    
    #word_tokenize accepts a string as an input, not a file.
 #   stop_words = set(stopwords.words('english'))
  #  words = formatted.split()
  #  for r in words:
  #      cleanr=clean(r)
  #      if not cleanr in stop_words:
   #    f.write(" "+cleanr)
  #        print (cleanr)
   # f.close()
    
    print (formatted)
# Out:
# b'AdvertisementSupported byHomework Therapists Job Help Solve Math Problems and Emotional OnesImageLeah Kesselman left is a clinical psychologist and one of dozens of New York coaches who work for Beyond BookSmartCreditSarah Blesener for The New York TimesBy Kyle SpencerApril On a recent Sunday Bari Hillman who works during the week as a clinical psychologist at a New York mental health clinic was perched at a clear plastic desk inside a yearolds Manhattan bedroom her shoeless feet resting on a fluffy white rug Dr Hillman was helping a private school sophomore manage her outsize worry over a longterm writing project The student had taped the project outline on the wall above the desk at Dr Hillmans prodding It was designed to serve both as a reminder that the project was due and an empowering indicator of progressDr Hillman mused about the way worry can morph into unhealthy avoidance the cathartic power of deep breathing and the soothing nature of todo listsDr Hillman represents a ne
# ...
